# %% [markdown]
# ***Clone Repo***

# %%
# !git clone https://github.com/theschoolofai/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 156, done.
# remote: Total 156 (delta 0), reused 0 (delta 0), pack-reused 156
# Receiving objects: 100% (156/156), 12.74 MiB | 13.44 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
ls
# Out:
# gdrive/  sample_data/  YoloV3/

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	     train.py
#  cfg		   __pycache__	  test_batch0.png   'ubdivisions=1'
#  data		   README.md	  test.py	     utils
#  detect.py	   results.json   ting		     vim.exe.stackdump
#  models.py	   results.png	  train_batch0.png   weights

# %%
#!python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave

# %% [markdown]
# **Training Model**

# %%
# !python train.py --data data/customdata/custom.data --batch 12 --cache --cfg cfg/yolov3-custom.cfg --epochs 200 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=12, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=200, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-04-26 05:01:22.490824: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (451 found, 0 missing, 0 empty, 0 duplicate, for 451 images): 100% 451/451 [00:00<00:00, 10162.63it/s]
# Caching images (0.3GB): 100% 451/451 [00:01<00:00, 356.94it/s]
# ...

# %% [markdown]
# ***Inference on video***

# %%
# !python detect.py --conf-thres 0.1 --output '/content/YoloV3/output' --iou-thres=0.6 --source '/content/YoloV3/Groottest.mp4'
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/YoloV3/output', save_txt=False, source='/content/YoloV3/Groottest.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/581) /content/YoloV3/Groottest.mp4: 320x512 Done. (0.035s)
# video 1/1 (2/581) /content/YoloV3/Groottest.mp4: 320x512 Done. (0.027s)
# video 1/1 (3/581) /content/YoloV3/Groottest.mp4: 320x512 Done. (0.027s)
# video 1/1 (4/581) /content/YoloV3/Groottest.mp4: 320x512 Done. (0.027s)
# video 1/1 (5/581) /content/YoloV3/Groottest.mp4: 320x512 Done. (0.027s)
# video 1/1 (6/581) /content/YoloV3/Groottest.mp4: 320x512 Done. (0.027s)
# ...
